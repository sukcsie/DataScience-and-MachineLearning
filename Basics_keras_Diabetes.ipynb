# %% [markdown]
# <a href="https://colab.research.google.com/github/sukcsie/DataScience-and-MachineLearning/blob/main/Basics_keras_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem Statement:** Build a predictive model of how likely someone is to get or have diabetes given their age, body mass index, glucose and insulin levels, skin thickness, etc.
#
# `Dataset`: https://www.kaggle.com/uciml/pima-indians-diabetes-database or you can also get this data from https://archive.ics.uci.edu/ml/support/diabetes.

# %%
# libraries
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# uploading a data file in colab
from google.colab import files # only needed if you use colab
files.upload() # only needed if you use colab

# load the data into the dataframe
# visualize the data
dataframe = pd.read_csv("diabetes.csv")
dataframe.head()
# Out:
#      <input type="file" id="files-1f7a884e-b305-42f4-be2a-178e7a779c1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f7a884e-b305-42f4-be2a-178e7a779c1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes (1).csv
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# ...

# %%
# remove and missing Values in the dataset
df_label = dataframe['Outcome']
df_features = dataframe.drop('Outcome', 1)
df_features.replace('?', -99999, inplace=True)
print(df_label.head())
df_features.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72  ...  33.6                     0.627   50
# 1            1       85             66  ...  26.6                     0.351   31
# 2            8      183             64  ...  23.3                     0.672   32
# 3            1       89             66  ...  28.1                     0.167   21
# 4            0      137             40  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
# one hot encoding for all the the type of labels
# For example we will make 1 into [1,0] and 0 into [0,1].
# NOTE: You can also use pandas.get_dummies() for one hot encoding

label = []
for lab in df_label:
    if lab == 1:
        label.append([1, 0])  # class 1
    elif lab == 0:
        label.append([0, 1])  # class 0

# %%
# separating out features and labels of the data
data = np.array(df_features)
label = np.array(label)
print(data.shape,label.shape)
# Out:
# (768, 8) (768, 2)

# %% [markdown]
# We can See the `Outcome Column` determines whether patient has diabetes or not (1-Diabetes,0-No Diabetes). Remaining other columns determine features which are essential for predicting.

# %%
# Split the data into features and labels (test and train)
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)
x_train.shape
# Out:
# (614, 8)

# %%
# Building the NN
# reate simple Keras neural network with 2 hidden layers 
# one with 500 and and other with 100 with 
# 8 input features and 2 labels to predict on

model = Sequential()
model.add(Dense(500, input_dim=8, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(x_train,y_train, epochs=1000, batch_size=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2218 - accuracy: 0.6580 - val_loss: 0.2129 - val_accuracy: 0.6558
# Epoch 2/1000
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.6564 - val_loss: 0.2174 - val_accuracy: 0.6558
# Epoch 3/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.6580 - val_loss: 0.1982 - val_accuracy: 0.7273
# Epoch 4/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2046 - accuracy: 0.6808 - val_loss: 0.2038 - val_accuracy: 0.6623
# Epoch 5/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.7101 - val_loss: 0.1973 - val_accuracy: 0.6818
# Epoch 6/1000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1882 - accuracy: 0.7101 - val_loss: 0.2011 - val_accuracy: 0.6818
# Epoch 7/1000
# ...

# %%
# predict with couple of training data; make sure you exclude the labels
test1 = np.array([x_train[0]])
test2 = np.array([x_train[1]])

result = model.predict_classes(test1)
# Out:
# WARNING:tensorflow:From <ipython-input-10-398bc26ca5d7>:5: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
# for better representation of the results
if result==0:
    print("NO Diabetes")
else:
    print("Diabetes")
# Out:
# Diabetes
